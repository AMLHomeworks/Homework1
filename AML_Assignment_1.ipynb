# %% [markdown]
# ## Advanced Machine Learning(2019/2020)
# ### Exercise 1: Image Filtering and Object Identification
#
# * **Students**:Musie Meressa Berhe(1851620), Nguyen Phu Hien(1836702), Maureen Dzifa Awumee Quist(1850579).

# %% [markdown]
# ##### Review
# In this assignment, basic image filtering is being implemented to an image using the numpy and pandas. Filtering is subjected to an image in order to achieve outputs such as smoothing(reducing the noise), enhancement(improving the constract), to extact informations about edges or corners and also to detect image patterns.
#
#
# In the identification part, query images are being compared the images  with different distance functions such as the intersection distance, the euclidean distance and the chi-square distance. The functions are evaluated through thier performance in combination with the different types of image representation.

# %% [markdown]
# ## Filtering

# %% [markdown]
# ### Question 1: Image Filtering
# #### _See results for image filtering for details and comments._

# %% [markdown]
# **Question 1a** Showing the vector of values of x defining the Gaussian filter.
#
# **Question 1b** Taking an image as input and showing the resulting convolution of the image with the Gaussian 2D kernel.
#
# **Question 1c** Using a Gaussian derivation filter in 1D to show the  vector of values of x defining the Gaussian filter.
#
# **Question 1d** With a sigma of 7.0, using th 1D Gassuain and the Gaussian derivative kernels on the test image and applying the various combination.
#
# **Question 1e** Returning two(2) copies of the input image, smoothed according to the sigma being the standard deviation and dervied in both directions x and y repectively.

# %%
import filter
# Out:
# Question 1a
# [0.00110988 0.00227733 0.00438967 0.00794866 0.01352113 0.0216067
#  0.03243549 0.04574138 0.06059748 0.07541479 0.08816882 0.0968345
#  0.09990836 0.0968345  0.08816882 0.07541479 0.06059748 0.04574138
#  0.03243549 0.0216067  0.01352113 0.00794866 0.00438967 0.00227733
#  0.00110988]
# Question 1b
# Question 1c
# Question 1d
# [[0.00063446 0.00096405 0.00143526 0.00209363 0.0029923  0.00419031
#   0.00574944 0.00772932 0.01018108 0.01313963 0.01661535 0.02058603
#   0.02499036 0.02972414 0.0346404  0.03955427 0.0442528  0.04850929
#   0.05210099 0.05482818 0.05653255 0.05711236 0.05653255 0.05482818
#   0.05210099 0.04850929 0.0442528  0.03955427 0.0346404  0.02972414
#   0.02499036 0.02058603 0.01661535 0.01313963 0.01018108 0.00772932
#   0.00574944 0.00419031 0.0029923  0.00209363 0.00143526 0.00096405
#   0.00063446]]
# DX...........
#  [[ 2.63436649e+14  3.81225133e+14  5.39183517e+14  7.45115909e+14
# ...

# %% [markdown]
# ### Results for Image Filtering

# %% [markdown]
# For x ranges from the values $[-3\sigma, 3\sigma]$, returns Gaussian values of Gx as given under question 1a of the filter solution.
#
# Comparing both images, the first image is the input image, where as the second image implementing a 2D Gassuain filter to smooth the image reducing or removing the nose, given us the picture to the left.
#
# The Gaussian derivative has seen from the plot above as compared to the gaussian function is a fluctation of x ranging from the values $[-3\sigma, 3\sigma]$, with its minimum at 4.
#
# From the above test image created with only a central pixel:
#
# applying the combinations of the Gaussian and Gaussian derivative kernels, it seen that:
#
# * the first combination of the Gassuian kernel and its transpose, smooths the central pixel.
# * the Gaussian kernel and the transpose of the Gaussian derivative kernel, provides an smoothed image showing colors of white and red. The red is must dominant as compared to the white but concentrates more at the top plane of the image.
# * when combinating the Gaussain derivative kernel, applying it first then the Gaussian kernel produces a smoothed image showing cloros of blue and white. As seen in the above combination, the blue is also dominant but concentates more at the the topper plane of the image.
# * with the four image, applying the Gaussian derivative kernel first before its transpose, it produces a smoothed image with 2 patches of white and black each. The two patches of each color are diagonally opposite to each other.
# * applying the Gaussian derivaitve kernel first then the tranpose Gaussian kernel or vice versa result in the same smoothed image, with 2 patches of whte and black, vertically divided.
#
# Smoothing an image is very important before applying the derivative filter because it reduces the noise in the image, to enable that of the derivtive kernel to easily detect edges or corners of the image.

# %% [markdown]
# ## Identification
# #### _See results for Identification for details and comments._

# %% [markdown]
# ### Question 2: Image Representation, Histogram Distances
#
# **Question 2a** uses the gray-value histogram for recognition of an image. That, it takes an image, converts into a gray image and computes an histogram of pixel intensity. This histogram of the image is then compared to the builtin python function numpy.histogram.
#
# Note: the pixel intensity varies from 0 to 255.
#
# **Question 2b** uses the RGB histogram  for recognition of an image. The first histogram is based on the full RGB(this is a joint of each color channel in the image) while the other is based on the RG (this is the joint of just the R and G color channel in the image).
# Using the Gaussian partial derivative, note that the actual image range will depend on the chosen filtering variance, computing the derivative.
#
# **Question 2c** Computing the distances. In order to compare histograms, there are 3 ways being implemented in this exercise
# * **the intersection distance**: here, smaller values represent that the histograms are similar
# * **the euclidean distance**: if the distance computed is equal to zero then the histograms in comparison are the same
# * **the chi-sqaure distance** This is basically to test if the distribtuion that is the histograms are different. This is method is very discriminant

# %% [markdown]
# ### Question 3: Object Identification
#
# **Question 3a**: testing for the suitability of the distance functions and image histograms implemented in **question 2**. Taking a list of model images and query images and returning the index of the closet model image for each of the given query images.
#
# **Question 3b**: showing the neigbors of a query image. That is for each of a given query image, show the model images which are closest to the query image given distance metric. In this particular question the chi-square distance metric was used.
#
# **Question 3c**: computing the recognition rate for different combinations of distance and histogram functions.

# %% [markdown]
# ### Question4: Performance Evaluation
#
# **Question 4a** Computing precision/recall pairs for a range of threshold values and then output the precision/recall curve (RPC).
#
# **Question 4b** Plotting RPC curves for different histogram types, distances and number of bins.

# %%
import identification
# Out:
# Question 2a
# Question 2b
# Question 2c
# Distance according to dist_l2 0.003096
# Distance according to dist_interset 0.295349
# Distance according to dist_chi2 0.332074
# distance functions: ['l2', 'intersect', 'chi2']
# histogram types: ['grayvalue', 'rgb', 'rg', 'dxdy']
# Comparison of images "./model/obj1__0.png" to "./model/obj91__0.png":
# [[3.21797282e-03 3.09561938e-03 5.10408729e-03 2.18390200e+06]
#  [1.34216309e-01 2.95349121e-01 2.52685547e-01 8.06274414e-02]
#  [1.11515118e-01 3.32074377e-01 3.36741002e-01 7.68621258e+02]]
#
#
# Comparison of images "./model/obj1__0.png" to "./model/obj94__0.png":
# [[2.19373703e-02 1.59698650e-02 1.75773501e-02 3.95845200e+06]
#  [3.81042480e-01 4.70092773e-01 4.38354492e-01 1.26953125e-01]
#  [5.56784161e-01 6.53055551e-01 7.18444634e-01 1.75341476e+03]]
#
#
# Legend:
# l2-grayvalue, l2-rgb, l2-rg, l2-dxdy
# intersect-grayvalue, intersect-rgb, intersect-rg, intersect-dxdy
# chi2-grayvalue, chi2-rgb, chi2-rg, chi2-dxdy
# Question 3a
# ...

# %% [markdown]
# ### Results For Identification

# %% [markdown]
# Comparing histogams, the histogram of the image compared to the builtin python function numpy.histogram.The first histogram is the computed with numpy. It is seen that both histograms are the exact, except for the scale which varies. The normalized_hist does not normalize its output.
#
# For the following histograms are results of the RGB, RG and Gaussian partial derivative in that order. But setting $\sigma = 3.0$ for this exercise.
#
# * Distance according to the euclidean distance is 0.003096
# * Distance according to the intersection distance is 0.295349
# * Distance according to the chi-sqaure distance is 0.332074.
#
# smaller values indicating that the histograms of the various images are similar.
# comparing image obj1__0.png to images obj91__0.png and model/obj94__0.png using the various distance functions.
#
# Finding the best match, for a query image returns the index of closest model image.
#
# The recognition rate which is given by the number of correct matches and the total number of queries was found to be 0.7528. Therefore, about 75% of the model images match the query images according to the intersection distance between RG-histograms with 30-binned histograms.
#
# Try and error:
# ##### euclidean
# * using euclidean between grayvalue with 30-bins , the recognition rate is 0.3933
# * euclidean between RGB-histograms with 30-bins, the recognition rate is 0.3933
# * euclidean between RG-histograms with 30-bins, the recognition rate is 0.4494
# * euclidean between dxdy with 30-bins, the recognition rate is 0.1348
#
# ##### intersection
# * using intersection between grayvalue with 30-bins , the recognition rate is 0.4943
# * intersection between RGB-histograms with 30-bins, the recognition rate is 0.8202
# * intersection between RG-histograms with 30-bins, the recognition rate is 0.7528
# * intersection between dxdy with 30-bins, the recognition rate is 0.1348
#
# ##### chi-square
# * Using chi-square between grayvalue, it is seen that the recognition rate is 0.5955
# * chi-square between RGB-histograms with 30-bins, the recognition rate is 0.7865
# * chi-square between RG-histograms with 30-bins, the recognition rate is 0.7528
# * chi-square between dxdy with 30-bins, the recognition rate is 0.1348
#
# It can be seen that, the highest recognition rate is 82% according to the intersection distance between RGB-histograms with 30-binned histograms.
#
#
# ##### Recall-Precision
# Comparing all the diagrams of the different histograms, it can be seen RGB and RG are almost similaar which that dxdy far off from the rest. The curves of the various distance computations for RGB, RG plots, see a gradually rise in 1-precision and recall till the finally converge at 1. It can be seen that the chi_square and the intersection distances
# reaches a higher precision and recall at an early stage as compared to euclidean distance(the blue curve).
#
# For the plot of the dxdy diagram, recall does not increase as 1 - precision increases but finally sees a rise as 1 - precision is between 0.6 and 0.8. All curves eventually converges at 1.
